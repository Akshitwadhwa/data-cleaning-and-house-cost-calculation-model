# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import rcParams
import math
import matplotlib as mpl
import matplotlib as mp
import numpy as no
#importing all the neccessary libraries

# %%
house_train = pd.read_csv('datasets/new_housing_data.csv')
house_train
# loading the new dataset
# Out:
#       Order  Lot Frontage  Lot Frontage.1  Garage Area House Style  \
# 0         1         141.0           141.0        528.0      1Story
# 1         2          80.0            80.0        730.0      1Story
# 2         3          81.0            81.0        312.0      1Story
# 3         4          93.0            93.0        522.0      1Story
# 4         5          74.0            74.0        482.0      2Story
# ...     ...           ...             ...          ...         ...
# 2925   2926          37.0            37.0        588.0        SLvl
# 2926   2927           NaN             NaN        484.0      1Story
# 2927   2928          62.0            62.0          0.0      SFoyer
# 2928   2929          77.0            77.0        418.0      1Story
# 2929   2930          74.0            74.0        650.0      2Story
#
#       Fireplaces Garage Type  Garage Cars  Yr Sold  SalePrice
# 0              2      Attchd          2.0     2010     215000
# ...

# %%
house_train.head(5)
# now we have the sale price in the end and we can make it in the y variable
# Out:
#    Order  Lot Frontage  Lot Frontage.1  Garage Area House Style  Fireplaces  \
# 0      1         141.0           141.0        528.0      1Story           2
# 1      2          80.0            80.0        730.0      1Story           0
# 2      3          81.0            81.0        312.0      1Story           0
# 3      4          93.0            93.0        522.0      1Story           2
# 4      5          74.0            74.0        482.0      2Story           1
#
#   Garage Type  Garage Cars  Yr Sold  SalePrice
# 0      Attchd          2.0     2010     215000
# 1      Attchd          1.0     2010     105000
# 2      Attchd          1.0     2010     172000
# 3      Attchd          2.0     2010     244000
# 4      Attchd          2.0     2010     189900

# %%
from sklearn.model_selection import train_test_split

x = house_train.drop(['SalePrice'] , axis= 1)
y = house_train['SalePrice']
y
# Changing the value of the x and y variable
# Out:
# 0       215000
# 1       105000
# 2       172000
# 3       244000
# 4       189900
#          ...
# 2925    142500
# 2926    131000
# 2927    132000
# 2928    170000
# 2929    188000
# Name: SalePrice, Length: 2930, dtype: int64

# %%
X_train , X_test , y_train , y_test = train_test_split(x , y ,test_size=0.2)
trained_model= X_train.join(y_train)
# joining both the data with the y data
trained_model
# here we can see that the values in the sale price have changed and all fallen into a new varible
# Out:
#       Order  Lot Frontage  Lot Frontage.1  Garage Area House Style  \
# 372     373          85.0            85.0        544.0      1Story
# 1792   1793          75.0            75.0        859.0      2Story
# 968     969          85.0            85.0        920.0      1Story
# 1177   1178          36.0            36.0        846.0      2Story
# 177     178          50.0            50.0        484.0      1.5Fin
# ...     ...           ...             ...          ...         ...
# 2729   2730         100.0           100.0        440.0      1Story
# 2097   2098          77.0            77.0       1052.0      2Story
# 1347   1348          51.0            51.0        468.0      1.5Fin
# 28       29          26.0            26.0        511.0      1Story
# 174     175          60.0            60.0        379.0      2Story
#
#       Fireplaces Garage Type  Garage Cars  Yr Sold  SalePrice
# 372            1      Attchd          2.0     2009      82500
# ...

# %%
trained_model.hist(figsize=(15 , 8))
# this is histogram
# Out:
# array([[<Axes: title={'center': 'Order'}>,
#         <Axes: title={'center': 'Lot Frontage'}>,
#         <Axes: title={'center': 'Lot Frontage.1'}>],
#        [<Axes: title={'center': 'Garage Area'}>,
#         <Axes: title={'center': 'Fireplaces'}>,
#         <Axes: title={'center': 'Garage Cars'}>],
#        [<Axes: title={'center': 'Yr Sold'}>,
#         <Axes: title={'center': 'SalePrice'}>, <Axes: >]], dtype=object)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
A = trained_model[['Lot Frontage' , 'Garage Area']]
B = trained_model['SalePrice']

# %%
A_train, A_test, B_train, B_test = train_test_split(A ,B, test_size=0.2, random_state=42)
# doing the a train and b train for the given data size

model = LinearRegression()

model.fit(A_train, B_train)
predictions = model.predict(A_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 6
#       2 # doing the a train and b train for the given data size
#       4 model = LinearRegression()
# ----> 6 model.fit(A_train, B_train)
#       7 predictions = model.predict(A_test)
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_base.py:609, in LinearRegression.fit(self, X, y, sample_weight)
#     605 n_jobs_ = self.n_jobs
# ...

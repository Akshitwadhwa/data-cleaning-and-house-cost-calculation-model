# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import rcParams
import math
import matplotlib as mpl
import matplotlib as mp
import numpy as no
#importing all the neccessary libraries

# %%
ames_url = 'https://raw.githubusercontent.com/wblakecannon/ames/master/data/housing.csv'

ames = pd.read_csv(ames_url)

# %%
ames.head(5)
# Out:
#    Unnamed: 0  Order        PID  MS SubClass MS Zoning  Lot Frontage  \
# 0           0      1  526301100           20        RL         141.0
# 1           1      2  526350040           20        RH          80.0
# 2           2      3  526351010           20        RL          81.0
# 3           3      4  526353030           20        RL          93.0
# 4           4      5  527105010           60        RL          74.0
#
#    Lot Area Street Alley Lot Shape  ... Pool Area Pool QC  Fence Misc Feature  \
# 0     31770   Pave   NaN       IR1  ...         0     NaN    NaN          NaN
# 1     11622   Pave   NaN       Reg  ...         0     NaN  MnPrv          NaN
# 2     14267   Pave   NaN       IR1  ...         0     NaN    NaN         Gar2
# 3     11160   Pave   NaN       Reg  ...         0     NaN    NaN          NaN
# 4     13830   Pave   NaN       IR1  ...         0     NaN  MnPrv          NaN
#
#   Misc Val Mo Sold Yr Sold Sale Type Sale Condition  SalePrice
# ...

# %%
len(ames)
# it is used to tell the lenght of the data which is given to us
# Out:
# 2930

# %%
ames.describe
# Out:
# <bound method NDFrame.describe of       Unnamed: 0  Order        PID  MS SubClass MS Zoning  Lot Frontage  \
# 0              0      1  526301100           20        RL         141.0
# 1              1      2  526350040           20        RH          80.0
# 2              2      3  526351010           20        RL          81.0
# 3              3      4  526353030           20        RL          93.0
# 4              4      5  527105010           60        RL          74.0
# ...          ...    ...        ...          ...       ...           ...
# 2925        2925   2926  923275080           80        RL          37.0
# 2926        2926   2927  923276100           20        RL           NaN
# 2927        2927   2928  923400125           85        RL          62.0
# 2928        2928   2929  924100070           20        RL          77.0
# 2929        2929   2930  924151050           60        RL          74.0
#
#       Lot Area Street Alley Lot Shape  ... Pool Area Pool QC  Fence  \
# ...

# %%
pd.options.display.max_columns = 100
print(ames)
# Out:
#       Unnamed: 0  Order        PID  MS SubClass MS Zoning  Lot Frontage  \
# 0              0      1  526301100           20        RL         141.0
# 1              1      2  526350040           20        RH          80.0
# 2              2      3  526351010           20        RL          81.0
# 3              3      4  526353030           20        RL          93.0
# 4              4      5  527105010           60        RL          74.0
# ...          ...    ...        ...          ...       ...           ...
# 2925        2925   2926  923275080           80        RL          37.0
# 2926        2926   2927  923276100           20        RL           NaN
# 2927        2927   2928  923400125           85        RL          62.0
# 2928        2928   2929  924100070           20        RL          77.0
# 2929        2929   2930  924151050           60        RL          74.0
#
#       Lot Area Street Alley Lot Shape Land Contour Utilities Lot Config  \
# ...

# %%
ames.describe()
ames.describe().round(1)
# here we have used the round function which basically rounds the values to the nearest 1st decimal
# Out:
#        Unnamed: 0   Order           PID  MS SubClass  Lot Frontage  Lot Area  \
# count      2930.0  2930.0  2.930000e+03       2930.0        2440.0    2930.0
# mean       1464.5  1465.5  7.144645e+08         57.4          69.2   10147.9
# std         846.0   846.0  1.887308e+08         42.6          23.4    7880.0
# min           0.0     1.0  5.263011e+08         20.0          21.0    1300.0
# 25%         732.2   733.2  5.284770e+08         20.0          58.0    7440.2
# 50%        1464.5  1465.5  5.354536e+08         50.0          68.0    9436.5
# 75%        2196.8  2197.8  9.071811e+08         70.0          80.0   11555.2
# max        2929.0  2930.0  1.007100e+09        190.0         313.0  215245.0
#
#        Overall Qual  Overall Cond  Year Built  Year Remod/Add  Mas Vnr Area  \
# count        2930.0        2930.0      2930.0          2930.0        2907.0
# mean            6.1           5.6      1971.4          1984.3         101.9
# ...

# %%
ames.isnull().sum()
# here we have used to clean the given data
# Out:
# Unnamed: 0        0
# Order             0
# PID               0
# MS SubClass       0
# MS Zoning         0
#                  ..
# Mo Sold           0
# Yr Sold           0
# Sale Type         0
# Sale Condition    0
# SalePrice         0
# Length: 83, dtype: int64

# %%
from IPython.display import FileLink

# %%
cleaned_file_path = 'cleaned_housing_data.csv'
ames.to_csv(cleaned_file_path, index=False)
FileLink(cleaned_file_path)
# Out:
# /Users/Lenovo/Desktop/4 sem/data-cleaning-and-house-cost-calculation-model/cleaned_housing_data.csv

# %% [markdown]
# # here we have got the cleaned csv file , which we are now going to use and import in the given area

# %%
ames.iloc[:,[5,6,7,82]].describe().round(1)
# this takes the 5 , 6, 7 , 82 columns and describes them
# Out:
#        Lot Frontage  Lot Area  SalePrice
# count        2440.0    2930.0     2930.0
# mean           69.2   10147.9   180796.1
# std            23.4    7880.0    79886.7
# min            21.0    1300.0    12789.0
# 25%            58.0    7440.2   129500.0
# 50%            68.0    9436.5   160000.0
# 75%            80.0   11555.2   213500.0
# max           313.0  215245.0   755000.0

# %%
ames.head(5)
# Out:
#    Unnamed: 0  Order        PID  MS SubClass MS Zoning  Lot Frontage  \
# 0           0      1  526301100           20        RL         141.0
# 1           1      2  526350040           20        RH          80.0
# 2           2      3  526351010           20        RL          81.0
# 3           3      4  526353030           20        RL          93.0
# 4           4      5  527105010           60        RL          74.0
#
#    Lot Area Street Alley Lot Shape Land Contour Utilities Lot Config  \
# 0     31770   Pave   NaN       IR1          Lvl    AllPub     Corner
# 1     11622   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2     14267   Pave   NaN       IR1          Lvl    AllPub     Corner
# 3     11160   Pave   NaN       Reg          Lvl    AllPub     Corner
# 4     13830   Pave   NaN       IR1          Lvl    AllPub     Inside
#
#   Land Slope Neighborhood Condition 1 Condition 2 Bldg Type House Style  \
# ...

# %%
ames.loc[: ,['Pool QC', 'Fence', 'Misc Feature', 'Alley', 'Fireplace Qu']]
# Out:
#      Pool QC  Fence Misc Feature Alley Fireplace Qu
# 0        NaN    NaN          NaN   NaN           Gd
# 1        NaN  MnPrv          NaN   NaN          NaN
# 2        NaN    NaN         Gar2   NaN          NaN
# 3        NaN    NaN          NaN   NaN           TA
# 4        NaN  MnPrv          NaN   NaN           TA
# ...      ...    ...          ...   ...          ...
# 2925     NaN  GdPrv          NaN   NaN          NaN
# 2926     NaN  MnPrv          NaN   NaN          NaN
# 2927     NaN  MnPrv         Shed   NaN          NaN
# 2928     NaN    NaN          NaN   NaN           TA
# 2929     NaN    NaN          NaN   NaN           TA
#
# [2930 rows x 5 columns]

# %%
# we are now going to make a model for the give dataset
ames_new= ames.drop(columns=['Alley' , 'Utilities' , 'Lot Shape' ,'Land Contour' ,'Land Slope' ])
ames_new
# removing the uncc
# Out:
#       Unnamed: 0  Order        PID  MS SubClass MS Zoning  Lot Frontage  \
# 0              0      1  526301100           20        RL         141.0
# 1              1      2  526350040           20        RH          80.0
# 2              2      3  526351010           20        RL          81.0
# 3              3      4  526353030           20        RL          93.0
# 4              4      5  527105010           60        RL          74.0
# ...          ...    ...        ...          ...       ...           ...
# 2925        2925   2926  923275080           80        RL          37.0
# 2926        2926   2927  923276100           20        RL           NaN
# 2927        2927   2928  923400125           85        RL          62.0
# 2928        2928   2929  924100070           20        RL          77.0
# 2929        2929   2930  924151050           60        RL          74.0
#
#       Lot Area Street Lot Config Neighborhood Condition 1 Condition 2  \
# ...

# %%
selected_columns = ['Order', 'Lot Frontage' ,'Lot Frontage' ,'Garage Area', 'House Style' ,'Fireplaces' ,'Garage Type' ,'Garage Cars','Yr Sold','SalePrice' ]
new_dataset = ames[selected_columns]
new_dataset.head(5)
# Out:
#    Order  Lot Frontage  Lot Frontage  Garage Area House Style  Fireplaces  \
# 0      1         141.0         141.0        528.0      1Story           2
# 1      2          80.0          80.0        730.0      1Story           0
# 2      3          81.0          81.0        312.0      1Story           0
# 3      4          93.0          93.0        522.0      1Story           2
# 4      5          74.0          74.0        482.0      2Story           1
#
#   Garage Type  Garage Cars  Yr Sold  SalePrice
# 0      Attchd          2.0     2010     215000
# 1      Attchd          1.0     2010     105000
# 2      Attchd          1.0     2010     172000
# 3      Attchd          2.0     2010     244000
# 4      Attchd          2.0     2010     189900

# %%
cleaned_file_path = 'new_housing_data.csv'
new_dataset.to_csv(cleaned_file_path, index=False)
FileLink(cleaned_file_path)
# Out:
# /Users/Lenovo/Desktop/4 sem/data-cleaning-and-house-cost-calculation-model/new_housing_data.csv

# %%
new_dataset.shape
# this is used to tell the shape of the given dataset we have
# this means we have 2930 rows and 10 columns
# Out:
# (2930, 10)
